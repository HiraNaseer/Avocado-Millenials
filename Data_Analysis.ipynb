# %% [markdown]
# # Import Libraries & Data

# %%
#Import libraries as required
import pandas as pd
from pathlib import Path

# %matplotlib inline

# %%
#Define the path 
csv_path = Path ("../Avocado Prices/avocado.csv")

#Read the csv and set the index
avc_df = pd.read_csv (csv_path, parse_dates = True, index_col = "Date")
avc_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# ...

# %% [markdown]
# # Check Data Types

# %%
avc_df.dtypes
# Out:
# Unnamed: 0        int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
# Use the `count` function to view count of non-null values for each column
avc_df.count()
# Out:
# Unnamed: 0      18249
# AveragePrice    18249
# Total Volume    18249
# 4046            18249
# 4225            18249
# 4770            18249
# Total Bags      18249
# Small Bags      18249
# Large Bags      18249
# XLarge Bags     18249
# type            18249
# year            18249
# region          18249
# dtype: int64

# %% [markdown]
# # Data Cleanup & Analysis

# %%
#Drop the unrequired column 'Unnamed: O'
avc_df.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
#Studying the relation between types of avocados & their volume
vol_df = avc_df.groupby(["Total Volume", "type"])
vol_df.head()
# Out:
#             AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...                  ...           ...      ...        ...     ...
# 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# ...

# %%
#Extract the two required columns using the iloc function
vol_df2 = vol_df.loc[:,["Total Volume", "type"]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25580/3702104414.py in <module>
#       1 #Extract the two required columns using the iloc function
# ----> 2 vol_df2 = vol_df.loc[:,["Total Volume", "type"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %%
#Extract the two required columns using the iloc function
vol_df.columns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25580/1386981648.py in <module>
#       1 #Extract the two required columns using the iloc function
# ----> 2 vol_df.columns()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'columns'
